# %% [markdown]
# <a href="https://colab.research.google.com/github/VinceManigo67/cs1-python-section-Manigo/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("Enter 1st number "))
num2 = int(input("Enter 2nd number "))
num3 = int(input("Enter 3rd number "))

#Find the biggest number

if num1 >= num2 and num1 >= num3:
  biggest = num1
elif num2 >= num1 and num2 >= num3:
  biggest = num2
else:
  biggest = num3

print("The biggest number is:", biggest)
# Out:
# Enter 1st number  5
# Enter 2nd number  7
# Enter 3rd number  3
# The biggest number is: 7
